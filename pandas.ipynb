# %%
#vksektmfmf pd라는 별칭으로 불러옴
import pandas as pd

# 파이썬 리스트를 통해 시리즈 생성
series_data = pd.Series([True, 3.14,'ABC'])

# 데이터 타입과 시리즈 출력
print(type(series_data))
print(series_data)
# Out:
# <class 'pandas.Series'>
# 0    True
# 1    3.14
# 2     ABC
# dtype: object

# %%
# 앞으로 데이터프레임 출력은 print() 함수 없이 출력하겠습니다.
df = pd.DataFrame({'c0':[1,2,3], 'c1':[4,5,6]})

# 데이터 타입과 데이터프레임 출력
print(type(df))
df
# Out:
# <class 'pandas.DataFrame'>
#    c0  c1
# 0   1   4
# 1   2   5
# 2   3   6

# %%
# 넷플릭스 데이터프레임 직접만들기
import pandas as pd
import numpy as np

# 1 딕셔너리에 넷플릭스 데이터 할당하기
dict_netflix = {
    'show_id': [1, 2, 3, 4, 5, 6, 7, 8],
    'type': ['TV Show', 'TV Show', 'Movie', 'Movie', 'Movie', 'TV Show', 'Movie', 'Movie'],
    'title': ['Squid Game', 'Stranger Things', 'Sherlock Holmes',
              'Iron Man & Captain America: Heroes United',
              'Bird Box', 'Anne with an E', 'About Time', 'Inception'],
    'director': [np.nan, np.nan, 'Guy Ritchie', 'Leo Riley',
                 'Susanne Bier', np.nan, 'Richard Curtis', 'Christopher Nolan'],
    'cast': ['Lee Jung-jae', 'Winona Ryder', 'Robert Downey Jr',
             'Adrian Pasdar', 'Sandra Bullock', 'Amybeth McNulty',
             'Domhnall Gleeson', 'Leonardo DiCaprio'],
    'country': [np.nan, 'United States', 'United States, Germany',
                'United States', 'United States', 'Canada',
                np.nan, 'United States'],
    'release_year': [2021, 2019, 2009, 2014, 2018, 2019, 2013, 2010],
    'duration': [300, 800, 128, 71, 124, 900, 123, 148],
    'listed_in': [np.nan, 'TV Horror', 'Action & Adventure',
                  np.nan, np.nan, np.nan, np.nan, np.nan]
}

# 2 딕셔너리로 데이터프레임 생성하기
netflix = pd.DataFrame(dict_netflix)
netflix
# Out:
#    show_id     type                                      title  \
# 0        1  TV Show                                 Squid Game
# 1        2  TV Show                            Stranger Things
# 2        3    Movie                            Sherlock Holmes
# 3        4    Movie  Iron Man & Captain America: Heroes United
# 4        5    Movie                                   Bird Box
# 5        6  TV Show                             Anne with an E
# 6        7    Movie                                 About Time
# 7        8    Movie                                  Inception
#
#             director               cast                 country  release_year  \
# 0                NaN       Lee Jung-jae                     NaN          2021
# 1                NaN       Winona Ryder           United States          2019
# 2        Guy Ritchie   Robert Downey Jr  United States, Germany          2009
# 3          Leo Riley      Adrian Pasdar           United States          2014
# ...

# %%
import pandas as pd

netflix = pd.read_csv("./netflix_titles.csv")
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# CSV 파일 저장하기
netflix.to_csv('netflix_new.csv', index=False)

# %%
# 판다스의 데이터 타입 알아보기
# 샘플 데이터 생성 후 판다스에서 읽어보기

kr_weather = pd.read_csv("./korea_weather_data.csv")
kr_weather
# Out:
#           date   city  temp_min_c  temp_max_c  humidity_pct  precip_mm  \
# 0   2026-01-27  Seoul        -9.1        -2.7            73       11.1
# 1   2026-01-28  Seoul         5.0        12.0            49        1.2
# 2   2026-01-29  Seoul        -5.5         4.9            45        0.0
# 3   2026-01-30  Seoul        -6.4         0.2            66        0.0
# 4   2026-01-31  Seoul        -6.4        -0.7            79        0.0
# 5   2026-02-01  Seoul        -0.2         4.6            63        0.0
# 6   2026-02-02  Seoul        -6.5         0.2            77        0.0
# 7   2026-02-03  Seoul        -3.9         0.4            60        0.0
# 8   2026-02-04  Seoul       -10.4         1.2            48        0.0
# 9   2026-02-05  Seoul       -10.1        -3.0            46        0.0
# 10  2026-02-06  Seoul        -3.7         1.9            59        0.0
# 11  2026-02-07  Seoul         0.2         5.7            50        0.0
# ...

# %%
# 데이터 내용 확인하기
# 데이터의 열과 행 확인하기

netflix = pd.read_csv('netflix_selena.csv')
# 열 이름 확인
list(netflix.columns)
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'release_year',
#  'duration',
#  'listed_in']

# %%
list(netflix.index)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]
