# %% [markdown]
# <a href="https://colab.research.google.com/github/DDORINY/study_AI_26/blob/main/02_%EB%AA%A8%EB%91%90%EC%9D%98_%EB%94%A5%EB%9F%AC%EB%8B%9D/04_%EA%B0%80%EC%9E%A5_%ED%9B%8C%EB%A5%AD%ED%95%9C_%EC%98%88%EC%B8%A1%EC%84%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 4. 파이썬 코딩으로 확인하는 최소 제곱

# %% [markdown]
# **01. 선형회귀의 정의**<br>
# "학생들의 중간고사 성적이 다 다르다" <br>
# "학생들의 중간고사 성적이 [   ]에 따라 다른다"<br> \
# []에 들어갈 내용을 "정보"라고 하면, 머신러닝과 딥러닝은 이 정보가 필요합니다.
#
# ---
# 여기서 정보요소를  x라고 하며, 이 x값에 따라 변하는 성적을  y라고 합니다. \
# 이를 정의하면 'x'값이 변함에 따라 'y'값도 변한다.\
# 이 정의 안에서 독립적으로 변할 수 잇는 값 x를 **독립변수**라고 합니다.\
# 독립변수에 따라 종속적으로 변하는 y를 **종속변수**라고 합니다.\
# 독립변수가 x 하나뿐이어서 이것만으로 정확히는 설명할 수 없을때는 x1.x2,x3 ...등 x 값을 여러개 준비해 놓을 수도 있습니다.
#
# ---
# **선형회귀**에서  하나의 x값으로 y값을 설명할 수 있다면 **단순선형회귀**라고 합니다.\
# x값이 여러개 필요하다면 **다중선형회귀**라고 합니다.
#
# ---
# **02.가장 훌륭한 예측선이란?**<br>
# 성적을 결정하는 여러 요소 중에 '공부한 시간'만 가지고 놓고 생각을 해본다면<br>
# 중간고사를 본 4명의 학생에게 각각 공부한 시간을 물어보고 이들의 중간고사 성적을 정리했다고 가정한다.
#
# 여기서 공부한 시간을 x라고 하고 성적을 y라고 할 때, 집합 X와 집합 Y를 같이 표현할 수 있다.
#
# X = {2,4,6,8}
# Y = {81,93,91,97}

# %% [markdown]
# ### 1. 환경 준비

# %%
import numpy as np

# %% [markdown]
# ### 2. 데이터 준비

# %%
# 공부한 시간과 점수를 각각 x, y라는 이름의 넘파이 배열로 만듭니다.
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])

# %% [markdown]
# 파이썬에서 리스트는 대괄호([])로 감싼 요소들을 쉼표(,)로 구분해 대입하여 만듭니다. <br>
# np.array() 함수를 사용하면 파이썬 리스트를 넘파이 배열로 바꾸어 여러가지 계산을 수행할 수 있습니다.

# %% [markdown]
# ### **[x와 y의 평균값]**
# 이제 최소 제곱근 공식으로 기울기 a의 값과 y 절편b의 값을 구해보겠습니다. \
# x의 모든 원소 평균을 구하는 넘파이 함수는 mean()입니다.\
# mx변수에는 x원소들의 평균값을 my 변수에는 y 원소들의 평균값을 넣습니다.

# %%
#x의 평균값을 구합니다.
mx = np.mean(x)

#y의 평균값을 구합니다.
my = np.mean(y)

# 출력으로 확인합니다.
print("x의 평균값:", mx)
print("y의 평균값:", my)
# Out:
# x의 평균값: 5.0
# y의 평균값: 90.5

# %% [markdown]
# #### **[기울기 공식의 분모와 분자]**
# 이제 앞서 살펴본 최소 제곱 법 공식 중 분모 값, \
# 즉'x의 각 원소와 x의 평균값의 차를 제곱하라'는 파이썬 명령을 만들 차례입니다.

# %%
# 기울기 공식의 분모 부분입니다.
divisor = sum([(i - mx)**2 for i in x])

# 기울기 공식의 분자 부분입니다.
def top(x, mx, y, my):
    d = 0
    for i in range(len(x)):
        d += (x[i] - mx) * (y[i] - my)
    return d
dividend = top(x, mx, y, my)

# 출력으로 확인합니다.
print("분모:", divisor)
print("분자:", dividend)
# Out:
# 분모: 20.0
# 분자: 46.0

# %% [markdown]
#  임의 변수 d의 초깃값을 0으로 설정한 후 x의 개수만큼 실행합니다 \
#  d에 x의 각 원소와 평균의 차, y의 각 원소와 평균의 차를 곱해서 차례로 더하는 최소 제곱법을 그대로 구현합니다.

# %% [markdown]
# ### 3. 기울기와 y 절편 구하기

# %%
# 기울기 a를 구하는 공식입니다.
a = dividend / divisor

# y 절편 b를 구하는 공식입니다.
b = my - (mx*a)

# 출력으로 확인합니다.
print("기울기 a =", a)
print("y절편 b =", b)
# Out:
# 기울기 a = 2.3
# y절편 b = 79.0

# %% [markdown]
# ## 6. 파이썬 코딩으로 확인하는 평균 제곱 오차

# %% [markdown]
# ### 1. 환경 준비

# %%
import numpy as np

# %% [markdown]
# ### 2. 데이터 준비

# %%
# 가상의 기울기 a와 y 절편 b를 정합니다.
fake_a=3
fake_b=76

# 공부 시간 x와 성적 y의 넘파이 배열을 만듭니다.
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])

# %% [markdown]
# ### 3. 평균 제곱 오차 구하기

# %%
# y=ax + b에 가상의 a,b 값을 대입한 결과를 출력하는 함수입니다.
def predict(x):
    return fake_a * x + fake_b

# 예측 값이 들어갈 빈 리스트를 만듭니다.
predict_result = []

# 모든 x 값을 한 번씩 대입하여 predict_result 리스트를 완성합니다.
for i in range(len(x)):
    predict_result.append(predict(x[i]))
    print("공부시간=%.f, 실제점수=%.f, 예측점수=%.f" % (x[i], y[i], predict(x[i])))
# Out:
# 공부시간=2, 실제점수=81, 예측점수=82
# 공부시간=4, 실제점수=93, 예측점수=88
# 공부시간=6, 실제점수=91, 예측점수=94
# 공부시간=8, 실제점수=97, 예측점수=100

# %%
# 평균 제곱 오차 함수를 각 y 값에 대입하여 최종 값을 구하는 함수입니다.
n=len(x)
def mse(y, y_pred):
    return (1/n) * sum((y - y_pred)**2)

# 평균 제곱 오차 값을 출력합니다.
print("평균 제곱 오차: " + str(mse(y,predict_result)))
# Out:
# 평균 제곱 오차: 11.0
