# %%
# 데이터 시각화 라이브러리, 맷플롯립(Matplotlib)
# 타이타닉 데이터를 활용하여
# 01. 맷플롯립 기본 개념 이해
# 02. 다양한 그래프 생성 방법 학습
# 03. 그래프 스타일 및 옵션 설정
# 04. 데이터 시각화를 통해 인사이트 도출

# Matplotlib은 파이썬에서 데이터를 시각화하기 위한 대표적인 라이브러리입니다.
# Matplotlib: Visualization with Python

# %%
# 맷플롯립 사용하기
import matplotlib.pyplot as plt

# %%
# 간단한 맷플롯립으로 그래프를 만들고 출력해본다.
# 첫 번째 리스트의 값은 X값, 두 번째 리스트의 값은 y로 적용
# 순서쌍 (x,y)으로 매칭된 값을 좌표평면 위에 그래프 시각화
plt.plot([1,2],[2,4])
plt.show()

# %%
# plot()함수에 리스트 하나만 전달하여 그래프 그리기

# 하나의 숫자 리스트 입력
# 리스트의 값들이 y값들이라고 가정하고 x값 [0,1,2,3]을 자동으로 만들어냄
# plt.show() 함수는 그래프를 화면에 나타나도록 함

y = [2,3,4,5]
plt.plot(y)
plt.show()

# %%
# 두 개의 숫자 리스트 입력
# 첫 번째 리스트의 값은 x값, 두 번째 리스트의 값은 y로 적용됨
# 순서쌍(x,y)으로 매칭된 값을 좌표평면 위에 그래프 시각화

x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y)
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.show()

# %%
# 범례 지정하기
# 범례는 그래프에서 데이터 종류를 표시하는 텍스트이다.

plt.plot([1,2,3,4],[1,4,9,16],label = 'Square')
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.legend()
plt.show()

# %%
# 범례의 위치를 위쪽 가운데로 지정하고 싶다면

# linspace() 함수로 넘파이 배열 생성
import numpy as np
x = np.linspace(0,10,100)
y1 = x
y2 = 2 * x
y3 = 0.5 * x
y4 = 3 * x

# 그래프 그리기
plt.plot(x,y1,label = 'y =x')
plt.plot(x,y2,label = 'y =2x')
plt.plot(x,y3,label = 'y =0.5x')
plt.plot(x,y4,label = 'y =3x')

# 범례 설정(ncol을 2로 설정하여 한 줄에 2개 표시)
plt.legend(loc='upper center', ncol=2)

plt.title('Simple Liner Plot Example')
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.show()

# %%
# 축 범위 지정하기

plt.plot([1,2,3,4],[3,6,9,12])
plt.xlim([0,5])
plt.ylim([0,15])
plt.show()

# %%
plt.plot([1,2,3,4,],[3,6,9,12])
plt.axis([0,5,0,15])
plt.show()

# %%
# 다양한 옵션으로 하나씩 확인하며 그려보기

x = np.linspace(1,10,100)
y = np.exp(x)

plt.subplot(2,2,1)
plt.plot(x,y)
plt.title('Liner Scale')

plt.subplot(2,2,2)
plt.plot(x,y)
plt.yscale('log')
plt.title('Logarithmic Scale (y-axis)')

plt.subplot(2,2,3)
plt.plot(x,y)
plt.xscale('log')
plt.title('Log-Linear Scale (x-axis)')

plt.subplot(2,2,4)
plt.plot(x,y)
plt.yscale('log')
plt.xscale('linear')
plt.title('Linear-Logarithmic Scale')

plt.tight_layout()
plt.show()

# %%
plt.plot([1,2,3],[4,4,4], '-', label='solid')     # 실선
plt.plot([1,2,3],[3,3,3], '--', label='dashed')   # 점선(긴)
plt.plot([1,2,3],[2,2,2], ':', label='dotted')    # 점선(짧은)
plt.plot([1,2,3],[1,1,1], '-.', label='dash-dot') # 점-선

plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper center', ncol=4)
plt.show()

# %%
plt.plot([1,2,3],[4,4,4], linestyle='dotted', label='dotted')
plt.plot([1,2,3],[3,3,3], linestyle='dashdot', label='dash-dot')

# %%
# 마커(marker) 설정
# 선 그래프에서 각 데이터 포인트를 표시하는 기호입니다.

plt.plot([4,5,6], "b")     # 파란색
plt.plot([3,4,5], "ro")    # red + circle
plt.plot([2,3,4], marker="s")   # square
plt.plot([1,2,3], marker="D")   # diamond
plt.plot([0,1,2], marker="$A$")
plt.show()

# %%
plt.plot([1,2,3,4],[2.0,3.3,6.3,10.5],color='violet')
plt.plot([1,2,3,4],[2.0,3.1,5.3,8.5],color='g')
plt.plot([1,2,3,4],[2.0,2.8,4.3,6.5], color= (0.1,0.2,0.3))
plt.plot([1,2,3,4],[2.0,2.5,3.3,4.5],color='#FF0000')
plt.show()

# %%
# 2024년 팬톤 컬러 :peach Fuzz(#F5C8B0)
pantone_2024_color ='#F5C8B0'

# 데이터 생성
x = [1,2,3,4,5]
y = [2,3,5,7,11]
plt.figure(figsize=(10, 6))
plt.plot(x,y, color = pantone_2024_color,linestyle='-', marker='o')
plt.title('Line Graph with 2024 Pantone color')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.grid(True)
plt.show()

# %%
# Matplotlib에서 그래프 제목(title)을 설정하는 방법
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

plt.title('Graph Title',
          fontsize=16,
          color='blue',
          fontweight='bold',
          loc='center',
          pad=100,
          backgroundcolor='lightgray')

plt.show()

# %%
# 슈퍼 타이틀 설정하기
x = [1,2,3,4,5]
y1 = [2,4,6,8,10]
y2 = [1,2,1,2,1]

# 첫 번째 서브 그래프
plt.subplot(2,1,1)
plt.plot(x,y1)
plt.title('Graph Sub Title 1', loc='left')

# 두 번째 서브 그래프
plt.subplot(2,1,2)
plt.plot(x,y2)
plt.title('Graph Sub Title 2', loc='left')

# 슈퍼 타이틀 설정 (전체 figure 제목)
plt.suptitle('Graph Super Title', fontsize=16)

# 서브 그래프 간격 자동 조정
plt.tight_layout()

plt.show()

# %%
# 그래프 배경 관련 옵션 사용하기

# %%
# 눈금 설정하기
import matplotlib.pyplot as plt

x = [1,2,3]
years = ['2030','2040','2050'] # year는 x축에 표시할 연도
values = [300,100,700] #values는 y축에 표시할 값

plt.bar(x,values,color=['r','g','b'])
# x축 눈금에 '2030', '2040', '2050'를 표시
plt.xticks(x,years)
plt.show()

# %%
# 그리드 설정하기
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[10,5,10,5])
# 그리드 활성화 및 설정
plt.grid(True, linestyle = '--',linewidth=0.5,color = 'gray', alpha = 0.7)
plt.show()

# %%
# 텍스트 추가하기
import matplotlib.pyplot as plt

categories = ['A','B','C','D']
values = [25,40,30,20]

# 막대 그래프 생성
plt.bar(categories, values, color ='skyblue')

# 각 막대 머리 위치에 텍스트 추가
for i, values in enumerate(values):
    # 옵션추가
    plt.text(i,values+1,str(values), ha='center', va='bottom', color = 'black', fontsize = 10)

plt.title('Bar chart with Text Annotations')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()

# %%
# 맷플롯립 그래프 그리기
import matplotlib.pyplot as plt

# 그래프 크기 설정
plt.figure(figsize=(6,6))

# 파란색 원 그리기
circle = plt.Circle((0.3,0.5),0.2, color = 'blue',fill=True)
plt.gca().add_patch(circle)

# 초록색 삼각형 그리기 (dashed)
triangle = plt.Polygon(((0.6,0.2),(0.8,0.2),(0.7,0.5)), closed =True,edgecolor = 'green',fill=False, linestyle='dashed')
plt.gca().add_patch(triangle)

# 그래프 제목 설정
plt.title('shapes')

# 축 범위 설정
plt.xlim(0,1)
plt.ylim(0,1)

# 축 비율 설정
plt.gca().set_aspect('equal',adjustable='box')

# 그리기
plt.show()

# %%
# 다양한 그래프 그려보기(1)
# 타이타닉 데이터셋 불러오기
import pandas as pd

# 타이타닉 CSV 파일 불러오기
titanic = pd.read_csv('titanic_selena.csv')

# %%
# 데이티ㅓ 처음 5개의 행 출력
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 열에 대한 요약 정보 확인
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
# 선 그래프 : 객실 등급에 따른 생존율 표시하기

titanic = pd.read_csv('titanic_selena.csv')
pclass_survived_mean = titanic.groupby('Pclass')['Survived'].mean().reset_index()
pclass_survived_mean
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
import matplotlib.pyplot as plt

# 선 그래프 그리기
plt.plot(
    pclass_survived_mean['Pclass'],
    pclass_survived_mean['Survived'],
    marker='o',
    linestyle='-',
    color='violet'
)

plt.title('Survival Rate Variation Across Passenger Classes')
plt.xlabel('Pclass')
plt.ylabel('Survival Rate')
plt.show()

# %%
titanic = pd.read_csv('titanic_selena.csv')

# 승선 항구에 따른 생존자 수 계산
survived_counts = titanic[titanic['Survived'] == 1]['Embarked'].value_counts()

survived_counts
# Out:
# Embarked
# S    217
# C     93
# Q     30
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.bar(
    survived_counts.index,
    survived_counts.values,
    color=['mediumorchid', 'darkviolet', 'indigo']
)

plt.title('Survived Count by Embarked Port on Titanic')
plt.xlabel('Embarked Port')
plt.ylabel('Count')

plt.xticks(
    survived_counts.index,
    ['Southampton', 'Cherbourg', 'Queenstown']
)

plt.legend(['Survived'], loc='upper right')
plt.grid(axis='y', linestyle='-', linewidth=0.7)

# 생존자 수 표시
for i, value in enumerate(survived_counts.values):
    plt.text(i, value + 1, str(value), ha='center', va='bottom')

plt.show()

# %%
# 수평 막대 그래프 : 성별에 따른 생존자 수 확인하기
titanic = pd.read_csv('titanic_selena.csv')

# 성별에 따른 생존자의 수 계산
survived_counts =titanic[titanic['Survived'] == 1]['Sex'].value_counts()
survived_counts
# Out:
# Sex
# female    233
# male      109
# Name: count, dtype: int64

# %%
# 수평막대 그래프 그리기
bars = plt.barh(survived_counts.index, survived_counts, color = ['darkturquoise','salmon'])
plt.title('Survived Count by Gender on Titanic')
plt.xlabel('Count')
plt.ylabel('Gender')
plt.legend(bars, ['Survived - Female','Survived - Male'], loc = 'upper right')

# 차이 강조를 위해 수평선 추가
plt.axvline(x=survived_counts['male'], color = 'gray', linestyle = '--', linewidth = 1)

# 생존자 수 표시
for i,value in enumerate(survived_counts):
    plt.text(value +1, i, str(value), ha = 'left', va = 'center')

plt.show()

# %%
# 산점도 그래프 : 나이와 요금, 생존 여부 확인하기
print(titanic.info(),'\n')

# 결측치 처리
titanic = titanic.dropna(subset=['Age','Fare','Survived'])
print(titanic.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
# None
#
# <class 'pandas.DataFrame'>
# Index: 714 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  714 non-null    int64
#  1   Survived     714 non-null    int64
#  2   Pclass       714 non-null    int64
#  3   Name         714 non-null    str
#  4   Sex          714 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        714 non-null    int64
#  7   Parch        714 non-null    int64
#  8   Ticket       714 non-null    str
#  9   Fare         714 non-null    float64
#  10  Cabin        185 non-null    str
#  11  Embarked     712 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 72.5 KB
# None

# %%
# 산점도 그래프 그리기
plt.figure(figsize =(12,8))
scatter = plt.scatter(x='Age', y='Fare', data = titanic, c = titanic['Survived'],
                      cmap = 'Set2', alpha = 0.7)
plt.title('Age and Fare Relationship with Survival on the Titanic')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.legend(handles=scatter.legend_elements()[0], title = 'Survived',labels = ['Not Survived','Survived'], loc = 'upper right')
plt.show()

# %%
# 파이차트 : 생존자, 사망자 비율 표현하기
titanic = pd.read_csv('titanic_selena.csv')
# 사망자와 생존자의 수 계산
survived_counts = titanic['Survived'].value_counts()
survived_counts
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# 파이차트 그리기
plt.figure(figsize = (8,8))
plt.pie(survived_counts,labels=['Not Survived','Survived'],colors=['orange','gold'], autopct='%0.1f%%', startangle = 90, shadow =True, explode = (0,0.1))
plt.title('Survival Distribution on the Titanic')
plt.show()

# %%
# 그래프를 표현하기 전에 데이터를 정리하기
# 처리 전
print(titanic.info(),'\n')

# 나이 결측치 처리 후
titanic = titanic.dropna(subset=['Age'])
print(titanic.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
# None
#
# <class 'pandas.DataFrame'>
# Index: 714 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  714 non-null    int64
#  1   Survived     714 non-null    int64
#  2   Pclass       714 non-null    int64
#  3   Name         714 non-null    str
#  4   Sex          714 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        714 non-null    int64
#  7   Parch        714 non-null    int64
#  8   Ticket       714 non-null    str
#  9   Fare         714 non-null    float64
#  10  Cabin        185 non-null    str
#  11  Embarked     712 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 72.5 KB
# None

# %%
# 히스토그램 그리기
plt.figure(figsize = (10,6))
plt.hist(titanic['Age'],bins=20, color ='seagreen', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Disrtibution of Ages on the Titanic')
plt.grid(axis='y', linestyle='-', linewidth=0.7)
plt.show()

# %%
# 다양한 그래프 그리기
# 결측치 처리
titanic = titanic.dropna(subset=['Age','Fare'])
# 상관행렬 계산
correlation_matrix = titanic.drop('PassengerId',axis=1).corr(numeric_only =True)
correlation_matrix
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.359653 -0.077221 -0.017358  0.093317  0.268189
# Pclass   -0.359653  1.000000 -0.369226  0.067247  0.025683 -0.554182
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.017358  0.067247 -0.308247  1.000000  0.383820  0.138329
# Parch     0.093317  0.025683 -0.189119  0.383820  1.000000  0.205119
# Fare      0.268189 -0.554182  0.096067  0.138329  0.205119  1.000000

# %%
plt.matshow(correlation_matrix, cmap='PuRd_r')
plt.colorbar()

# %%
# 그래프로 표현할 나이대별 생존자와 사망자 수 구하기
age_groups = pd.cut(titanic['Age'], bins=range(0,81,5))
# Age, Survived 기준으로 그룹화
survived_counts = titanic.groupby([age_groups,'Survived'], observed=False).size().unstack().fillna(0)
survived_counts
# Out:
# Survived   0   1
# Age
# (0, 5]    13  31
# (5, 10]   13   7
# (10, 15]   8  11
# (15, 20]  63  33
# (20, 25]  80  42
# (25, 30]  66  42
# (30, 35]  47  41
# (35, 40]  39  28
# (40, 45]  30  17
# (45, 50]  23  16
# (50, 55]  14  10
# (55, 60]  11   7
# (60, 65]  10   4
# (65, 70]   3   0
# (70, 75]   4   0
# (75, 80]   0   1

# %%
# 나이대별 생존자와 사망자 수를 영역 채우기 그래프로 시각화

# 영역 채우기 그래프 그리기
plt.figure(figsize=(10,6))
plt.fill_between(survived_counts.index.astype(str), survived_counts[1],color='purple', alpha=0.9,label='Survived') # 나이대별 생존자
plt.fill_between(survived_counts.index.astype(str), survived_counts[0],color='hotpink', alpha=0.6,label='Not Survived') # 나이대별 생존자
plt.title('Survival by Age Group on Titanic')
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()
